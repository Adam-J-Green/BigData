# %% [markdown]
# # 1.0 Model Creation and Training

# %%
#installing necessary libraries
# !pip install yfinance
# !pip install findspark
# !pip install pyspark
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.7)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317130 sha256=272d989ef0afeb0ea0b45aedcf9761599b819d420b1cf3ec361518698384e413
#   Stored in directory: /root/.cache/pip/wheels/7b/1b/4b/3363a1d04368e7ff0d408e57ff57966fcdf00583774e761327
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd
import csv
import datetime
import yfinance as yf
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from bs4 import BeautifulSoup as bs
import requests
from pyspark.sql.functions import sum,max,min,mean,count
import datetime as dt
import pyspark
from pyspark.sql import SparkSession
import findspark
import yaml
from yaml.loader import SafeLoader
from os.path import abspath
# !git clone https://github.com/JollygreenG-10/BigData.git
# Out:
# Cloning into 'BigData'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 132 (delta 9), reused 0 (delta 0), pack-reused 77
# Receiving objects: 100% (132/132), 8.36 MiB | 19.36 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %% [markdown]
# ## 1.1 Read in CSV Files Containing Data for Target Companies

# %%
from os import listdir
import pandas as pd
path = '/content/BigData/Project_Deliverables_PansyAhmed_AdamGreen/data/'

from sklearn.preprocessing import MinMaxScaler
#Function to read in csv files and scale columns for data where scaling of predictions is eventually needed
def scale(path):
    scaler_list = []
    target_list = []
    feat_list = []
    for item in listdir(path):
        df = pd.read_csv(path + str(item))
        print(str(item))
        df['date'] = pd.to_datetime(df['date'])
        df = df.set_index('date')
        #create scaler instances
        scaler = MinMaxScaler(feature_range=(0,1))
        target_scaler = MinMaxScaler(feature_range = (0,1))
        data = df.drop(['ticker'],axis=1)
        # scale features and target columns
        target = target_scaler.fit_transform(data[['target']])
        target = target.flatten()
        scaler_list.append(target_scaler)
        target_list.append(target)
        X_feat = data.drop(['target'], axis = 1)
        for col in X_feat.columns:
            X_feat[col] = scaler.fit_transform(X_feat[[col]])
        feat_list.append(X_feat)
    return scaler_list, target_list, feat_list
scaler_list, target_list, feat_list = scale(path)
# Out:
# MSFT_dataframe.csv
# GOOG_dataframe.csv

# %%
#Split training and test data (microsoft and google) was well as features and targets
test_data = feat_list[0]   
test_target = target_list[0]
train_data = feat_list[1] 
train_target = target_list[1]
print(train_data.reset_index().info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1802 entries, 0 to 1801
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1802 non-null   datetime64[ns]
#  1   open        1802 non-null   float64
#  2   high        1802 non-null   float64
#  3   low         1802 non-null   float64
#  4   close       1802 non-null   float64
#  5   adj_close   1802 non-null   float64
#  6   volume      1802 non-null   float64
#  7   tenmda      1802 non-null   float64
#  8   twentymda   1802 non-null   float64
#  9   fiftymda    1802 non-null   float64
#  10  hundredmda  1802 non-null   float64
#  11  EWMA_20     1802 non-null   float64
#  12  EWMA_50     1802 non-null   float64
#  13  EWMA_100    1802 non-null   float64
#  14  rsi         1802 non-null   float64
#  15  MiddleBand  1802 non-null   float64
#  16  UpperBand   1802 non-null   float64
#  17  LowerBand   1802 non-null   float64
#  18  sent_score  1802 non-null   float64
# dtypes: datetime64[ns](1), float64(18)
# memory usage: 267.6 KB
# None

# %%
# Split data into X_train and y_train data sets
import numpy as np
def lstm_split(data,target,steps):
      X = []
      y = []
      # Creating a data structure with 10 time-steps and 1 output
      for i in range(10, steps):
          X.append(data[i-10:i])
          y.append(target[i])  
      return np.array(X),np.array(y)
 
X1,y1 = lstm_split(train_data, train_target,len(train_data))

#Define Training and Test Datasets
def train_split(x1, y1, train_data):
  train_split = 0.9
  split_idx = int(np.ceil(len(X1)*train_split))
  date_index = train_data.index
 
  X_train,X_test = X1[:split_idx],X1[split_idx:]
  y_train,y_test = y1[:split_idx],y1[split_idx:]
  X_train_date,X_test_date = date_index[:split_idx],date_index[split_idx:]
  return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_split(X1, y1, train_data)
print(X1.shape,X_train.shape,X_test.shape,y_test.shape,y_train.shape)
# Out:
# (1792, 10, 18) (1613, 10, 18) (179, 10, 18) (179,) (1613,)

# %% [markdown]
# # 2.0 Setup the models LSTM & Prophet models for a single stock

# %% [markdown]
# ## 2.1 Configure the base LSTM model
# This process involved running a random search function to select best hyperparameters for the network. The results of this search are availble below.

# %%
# !pip install tensorflow
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.metrics import Precision
from keras.optimizers import Adam
# !pip install keras_tuner
import keras_tuner

#define function to create model, optional hyperparameters included to be selected during training
LR = 0.05
def build_model(hp):
  model = Sequential()
  hidden = hp.Choice('n_hidden', [0,1,2,3])
  model.add(LSTM(units = hp.Int('neurons_visible', min_value = X_train.shape[2], max_value = 100, step = 20),
                activation = hp.Choice('activate1', ['sigmoid', 'relu']),
                input_shape = (X_train.shape[1], X_train.shape[2]),
                return_sequences = True if hidden >0 else False))
  #Configure hidden layers based on random search determined hidden layer number
  if hidden > 0:
    for num in range(hidden):
      model.add(Dropout(hp.Float('dropout' +str(num+1), min_value = 0.1, max_value = 0.9, step = 0.3)))
      model.add(LSTM(units = hp.Int('neurons_hidden'+str(num+1), min_value = 20, max_value = 50, step = 10),
                     activation = 'relu', return_sequences = True if num != hidden else False))
      
  model.add(Dropout(0.5))
  model.add(Dense(units = 1, activation = 'sigmoid'))

  #compile the model
  model.compile(loss = 'mean_squared_error', optimizer = Adam(lr = LR), metrics = ['mae'])
  
  return model

#set learning rate and early stopping callbacks
LR_decay = ReduceLROnPlateau('loss', patience=1, verbose=0, 
                             factor=0.5, min_lr=1e-8)
Early_stop = EarlyStopping(monitor='loss', min_delta=0, 
                           patience=25, verbose=1, mode='auto',
                           baseline=0, restore_best_weights=True)
#arrange random search class
tune = keras_tuner.RandomSearch(build_model, objective = 'val_loss', max_trials = 25, seed = 1)

#complete training 
tune.search(X_train, y_train, epochs = 200, batch_size = 20, validation_data = (X_test, y_test), callbacks = [LR_decay, Early_stop])

LSTM_model = tune.get_best_models()[0]
LSTM_model.save('main_models/LSTM_model1.h5')
hyperparameters = tune.get_best_hyperparameters()[0]
print(hyperparameters.values)
# Out:
# Trial 25 Complete [00h 00m 45s]
# val_loss: 0.07022944837808609
#
# Best val_loss So Far: 0.0007448047399520874
# Total elapsed time: 00h 14m 20s
# {'n_hidden': 0, 'neurons_visible': 78, 'activate1': 'sigmoid', 'dropout1': 0.4, 'neurons_hidden1': 20, 'dropout2': 0.1, 'neurons_hidden2': 20, 'dropout3': 0.4, 'neurons_hidden3': 50}

# %% [markdown]
# # Test Base LSTM Model on Microsoft Validation Data

# %%
# function to test LSTM predictions
def testmodel(m_path, trainset ):
  from keras.models import load_model
  model = load_model(m_path)
  m_pred = model.predict(trainset)
  print(m_pred.shape)
  return m_pred

# %%
#test LSTM model using X_train for MSFT
LSTM_MSFT_test = testmodel('main_models/LSTM_model1.h5', X_test)
LSTM_MSFT_test.shape
LSTM_MSFT_pre_saved = testmodel('/content/BigData/Project_Deliverables_PansyAhmed_AdamGreen/main_models/LSTM_model1.h5', X_test)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 6/6 [==============================] - 0s 4ms/step
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# (179, 1)
# 6/6 [==============================] - 0s 3ms/step
# (179, 1)

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(y_test)+1, 1)
plt.plot(x,LSTM_MSFT_test.flatten(), "r", label= "Predicted")
plt.plot(x,y_test, "b", label= "Target")
plt.plot(x, LSTM_MSFT_pre_saved.flatten(), 'green', label = 'Pre-saved')
#plt.plot(x, LSTM_MSFT_long.flatten(), 'orange', label = 'long_train')
plt.title(" LSTM MSFT Predicted vs target trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.2 Configure the Prophet Model

# %%
from prophet import Prophet
from sklearn.metrics import mean_squared_error
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.model_selection import ParameterGrid
# !pip install yfinance
import yfinance as yf
import datetime as dt

#Generate basic financial data from yfinance for prophet training
def prophet_data(ticker, start_day, month, year):
    delta = dt.timedelta(days = 150)
    data = yf.download(ticker, (dt.date(year, month, start_day) - delta)).reset_index()
    print(data.head())
    data = data.rename(columns = {'Date':'ds', 'Open':'open', 'High':'high', 'Low':'low', 'Close':'close', 'Adj Close': 'y', 'Volume':'volume'})
    print(data.head())
    data = data.loc[:,['ds', 'y']]
    return data

MSFT_data = prophet_data('MSFT',1, 1,2016)
GOOG_data = prophet_data('GOOG', 1, 1, 2016)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.7)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (40.0.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2015-08-04  46.750000  47.709999  46.680000  47.540001  41.953983  33403900
# 1 2015-08-05  47.980000  48.410000  47.540001  47.580002  41.989285  26959700
# 2 2015-08-06  47.709999  47.770000  46.330002  46.619999  41.142094  27368000
# 3 2015-08-07  46.389999  46.779999  46.259998  46.740002  41.247974  19163000
# 4 2015-08-10  46.950001  47.490002  46.840000  47.330002  41.768665  23079900
#           ds       open       high        low      close          y    volume
# 0 2015-08-04  46.750000  47.709999  46.680000  47.540001  41.953983  33403900
# 1 2015-08-05  47.980000  48.410000  47.540001  47.580002  41.989285  26959700
# 2 2015-08-06  47.709999  47.770000  46.330002  46.619999  41.142094  27368000
# 3 2015-08-07  46.389999  46.779999  46.259998  46.740002  41.247974  19163000
# 4 2015-08-10  46.950001  47.490002  46.840000  47.330002  41.768665  23079900
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2015-08-04  31.421000  31.740499  31.358000  31.462500  31.462500  29818000
# 1 2015-08-05  31.716499  32.393002  31.658001  32.188999  32.188999  46686000
# 2 2015-08-06  32.250000  32.268951  31.612499  32.133999  32.133999  31452000
# 3 2015-08-07  32.011501  32.133999  31.485500  31.764999  31.764999  28078000
# 4 2015-08-10  31.974001  32.172001  31.562450  31.686501  31.686501  36184000
#           ds       open       high        low      close          y    volume
# 0 2015-08-04  31.421000  31.740499  31.358000  31.462500  31.462500  29818000
# 1 2015-08-05  31.716499  32.393002  31.658001  32.188999  32.188999  46686000
# 2 2015-08-06  32.250000  32.268951  31.612499  32.133999  32.133999  31452000
# 3 2015-08-07  32.011501  32.133999  31.485500  31.764999  31.764999  28078000
# 4 2015-08-10  31.974001  32.172001  31.562450  31.686501  31.686501  36184000

# %%
# Define parameter grid to search over
param_grid = {
    'seasonality_mode': ['additive', 'multiplicative'],
    'changepoint_prior_scale': [0.01, 0.1, 1.0],
    'seasonality_prior_scale': [0.01, 0.1, 1.0],
}

# Initialize minimum error and best parameters
min_error = float('inf')
best_params = {}

# Loop through all parameter combinations
for params in ParameterGrid(param_grid):
    print('Testing parameters:', params)

    # Initialize Prophet model with specified hyperparameters
    model = Prophet(**params)
    model.fit(MSFT_data)

    # Perform time series cross-validation
    df_cv = cross_validation(model=model, initial='1000 days', horizon='10 days', period='10 days')

    # Calculate performance metrics
    df_metrics = performance_metrics(df_cv)

    # Calculate mean cross-validation error
    mean_cv_error = df_metrics['mse'].mean()

    # Update minimum error and best parameters if new minimum is found
    if mean_cv_error < min_error:
        min_error = mean_cv_error
        best_params = params

# Print best hyperparameters and corresponding error
print('Best parameters:', best_params)
print('Minimum cross-validation error:', min_error)

# %% [markdown]
# ### 2.2.1 Train Prophet Models for Microsoft and Google

# %%
# We use the best parameter to fit the model
def get_data(df):
  Best_parameters={'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
  # We use the best parameter to fit the model
  final_model = Prophet(**Best_parameters)
  final_model.fit(df)
  df = cross_validation(model=final_model, initial='124 days', horizon='10 days', period='10 days')
  return df

#generate msft and google prediction datasets 
GOOG_data = get_data(GOOG_data)[['ds', 'yhat']]
MSFT_data = get_data(MSFT_data)[['ds', 'yhat']]
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ptb49xwp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/3wy6tlte.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43356', 'data', 'file=/tmp/tmprjsbnnc6/ptb49xwp.json', 'init=/tmp/tmprjsbnnc6/3wy6tlte.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model6yx18wh6/prophet_model-20230513155629.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 271 forecasts with cutoffs between 2015-12-10 00:00:00 and 2023-05-02 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/271 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ss06f8iu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/z0f9qawx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1078', 'data', 'file=/tmp/tmprjsbnnc6/ss06f8iu.json', 'init=/tmp/tmprjsbnnc6/z0f9qawx.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelasyvnxd6/prophet_model-20230513155632.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 15:56:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2b2m8fcp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/u51rgxdo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52695', 'data', 'file=/tmp/tmprjsbnnc6/2b2m8fcp.json', 'init=/tmp/tmprjsbnnc6/u51rgxdo.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model880cmuf4/prophet_model-20230513155634.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 15:56:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/iur9uh50.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ivoq6mew.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30131', 'data', 'file=/tmp/tmprjsbnnc6/iur9uh50.json', 'init=/tmp/tmprjsbnnc6/ivoq6mew.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelxzmyo5md/prophet_model-20230513155635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/yr9qc8z5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/anjaohs7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72958', 'data', 'file=/tmp/tmprjsbnnc6/yr9qc8z5.json', 'init=/tmp/tmprjsbnnc6/anjaohs7.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeldboj9kcp/prophet_model-20230513155635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/skim1gpd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/nrk70sfd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92170', 'data', 'file=/tmp/tmprjsbnnc6/skim1gpd.json', 'init=/tmp/tmprjsbnnc6/nrk70sfd.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelv7ppskx_/prophet_model-20230513155635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/hqvud3dd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/y8f9ydem.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52869', 'data', 'file=/tmp/tmprjsbnnc6/hqvud3dd.json', 'init=/tmp/tmprjsbnnc6/y8f9ydem.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model8_sk5if1/prophet_model-20230513155635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/isonvydf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/fl3tvo95.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56757', 'data', 'file=/tmp/tmprjsbnnc6/isonvydf.json', 'init=/tmp/tmprjsbnnc6/fl3tvo95.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelar3fljcw/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/j7mthzqw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/plef3_oj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45076', 'data', 'file=/tmp/tmprjsbnnc6/j7mthzqw.json', 'init=/tmp/tmprjsbnnc6/plef3_oj.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelp6thefno/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/wawkltgc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/w0u33xxf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73259', 'data', 'file=/tmp/tmprjsbnnc6/wawkltgc.json', 'init=/tmp/tmprjsbnnc6/w0u33xxf.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelxrc9w1b2/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/mga1za_f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/pyxcbex6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3341', 'data', 'file=/tmp/tmprjsbnnc6/mga1za_f.json', 'init=/tmp/tmprjsbnnc6/pyxcbex6.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model9kw53iuq/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/zk2ell9_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/opz8w_y4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98181', 'data', 'file=/tmp/tmprjsbnnc6/zk2ell9_.json', 'init=/tmp/tmprjsbnnc6/opz8w_y4.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelhsx41rhh/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tsw4973i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/q5bwhslz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96521', 'data', 'file=/tmp/tmprjsbnnc6/tsw4973i.json', 'init=/tmp/tmprjsbnnc6/q5bwhslz.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelcofpan_q/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/pn11w1t1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/k0sq1rp4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86711', 'data', 'file=/tmp/tmprjsbnnc6/pn11w1t1.json', 'init=/tmp/tmprjsbnnc6/k0sq1rp4.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelj970s_d1/prophet_model-20230513155636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ad47orq4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ip8irk47.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9247', 'data', 'file=/tmp/tmprjsbnnc6/ad47orq4.json', 'init=/tmp/tmprjsbnnc6/ip8irk47.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelf_1wplkq/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tm5n9yf9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/9i0fzyx2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12156', 'data', 'file=/tmp/tmprjsbnnc6/tm5n9yf9.json', 'init=/tmp/tmprjsbnnc6/9i0fzyx2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model4vl2smbl/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/vpr4ewyd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/pdhwf9g3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57708', 'data', 'file=/tmp/tmprjsbnnc6/vpr4ewyd.json', 'init=/tmp/tmprjsbnnc6/pdhwf9g3.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeltl4hkjev/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ev3p7ycr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/nbkavf6a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75925', 'data', 'file=/tmp/tmprjsbnnc6/ev3p7ycr.json', 'init=/tmp/tmprjsbnnc6/nbkavf6a.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeljsihxulq/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ffnrb7di.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/l6s_p80d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75143', 'data', 'file=/tmp/tmprjsbnnc6/ffnrb7di.json', 'init=/tmp/tmprjsbnnc6/l6s_p80d.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model8qznur3i/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/9ornzmdg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/6q7eosr2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11693', 'data', 'file=/tmp/tmprjsbnnc6/9ornzmdg.json', 'init=/tmp/tmprjsbnnc6/6q7eosr2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelj0_slzag/prophet_model-20230513155637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/g7gqg70m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/lcj5l6ob.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19824', 'data', 'file=/tmp/tmprjsbnnc6/g7gqg70m.json', 'init=/tmp/tmprjsbnnc6/lcj5l6ob.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model0wlkkgd5/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/16oq6tz9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/lve92p2i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75346', 'data', 'file=/tmp/tmprjsbnnc6/16oq6tz9.json', 'init=/tmp/tmprjsbnnc6/lve92p2i.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelbrah9y28/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/dsr7l33z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/cco_z70h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51780', 'data', 'file=/tmp/tmprjsbnnc6/dsr7l33z.json', 'init=/tmp/tmprjsbnnc6/cco_z70h.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model26nr3he5/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/wi9zk4nh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/r16jyfrz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62987', 'data', 'file=/tmp/tmprjsbnnc6/wi9zk4nh.json', 'init=/tmp/tmprjsbnnc6/r16jyfrz.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model1jitkwbe/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ie7ni10h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/7yk41af4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99932', 'data', 'file=/tmp/tmprjsbnnc6/ie7ni10h.json', 'init=/tmp/tmprjsbnnc6/7yk41af4.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model1zeit4qz/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tpsf6b17.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2pnli9wl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21134', 'data', 'file=/tmp/tmprjsbnnc6/tpsf6b17.json', 'init=/tmp/tmprjsbnnc6/2pnli9wl.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model8or9w3_9/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/r2lkl7u6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/rev28l7p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60348', 'data', 'file=/tmp/tmprjsbnnc6/r2lkl7u6.json', 'init=/tmp/tmprjsbnnc6/rev28l7p.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelbz6mgom4/prophet_model-20230513155638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/87x23p3k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/mgam1y1n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85305', 'data', 'file=/tmp/tmprjsbnnc6/87x23p3k.json', 'init=/tmp/tmprjsbnnc6/mgam1y1n.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelyhk6n538/prophet_model-20230513155639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/i75ktlr8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/fdtnot8l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21080', 'data', 'file=/tmp/tmprjsbnnc6/i75ktlr8.json', 'init=/tmp/tmprjsbnnc6/fdtnot8l.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeldoh7b4k5/prophet_model-20230513155639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ucopiw6c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/bbrle_dh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40866', 'data', 'file=/tmp/tmprjsbnnc6/ucopiw6c.json', 'init=/tmp/tmprjsbnnc6/bbrle_dh.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model9jfg8khy/prophet_model-20230513155639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/a_xr26d1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/4_3_r1fv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84498', 'data', 'file=/tmp/tmprjsbnnc6/a_xr26d1.json', 'init=/tmp/tmprjsbnnc6/4_3_r1fv.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelq20eqgim/prophet_model-20230513155639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/mam4bf8m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2ugemo1c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26885', 'data', 'file=/tmp/tmprjsbnnc6/mam4bf8m.json', 'init=/tmp/tmprjsbnnc6/2ugemo1c.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelytb5ixfq/prophet_model-20230513155639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/v9efxpel.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/7cbbzja2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51041', 'data', 'file=/tmp/tmprjsbnnc6/v9efxpel.json', 'init=/tmp/tmprjsbnnc6/7cbbzja2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeljarfx169/prophet_model-20230513155640.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/0spz8noq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/5n5rnar2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13339', 'data', 'file=/tmp/tmprjsbnnc6/0spz8noq.json', 'init=/tmp/tmprjsbnnc6/5n5rnar2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model2nxag7h9/prophet_model-20230513155640.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/8a886sai.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ljzvsg9b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9874', 'data', 'file=/tmp/tmprjsbnnc6/8a886sai.json', 'init=/tmp/tmprjsbnnc6/ljzvsg9b.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelny8837tb/prophet_model-20230513155640.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/v3m8yakq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/clwufysi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90819', 'data', 'file=/tmp/tmprjsbnnc6/v3m8yakq.json', 'init=/tmp/tmprjsbnnc6/clwufysi.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeljbufpavs/prophet_model-20230513155640.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/x6d4oqyd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/9i93zu22.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41681', 'data', 'file=/tmp/tmprjsbnnc6/x6d4oqyd.json', 'init=/tmp/tmprjsbnnc6/9i93zu22.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelaxr4stfc/prophet_model-20230513155641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/6qn814qy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/vwj5f4q5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33209', 'data', 'file=/tmp/tmprjsbnnc6/6qn814qy.json', 'init=/tmp/tmprjsbnnc6/vwj5f4q5.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model3bl_4v_g/prophet_model-20230513155641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/7juh7igk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/jeki6vfu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63499', 'data', 'file=/tmp/tmprjsbnnc6/7juh7igk.json', 'init=/tmp/tmprjsbnnc6/jeki6vfu.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model_c2qjvzw/prophet_model-20230513155641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/lz82crat.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/0izemv0t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35661', 'data', 'file=/tmp/tmprjsbnnc6/lz82crat.json', 'init=/tmp/tmprjsbnnc6/0izemv0t.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelc91v9kly/prophet_model-20230513155641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/8snz1lyw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/txnfh7m_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42876', 'data', 'file=/tmp/tmprjsbnnc6/8snz1lyw.json', 'init=/tmp/tmprjsbnnc6/txnfh7m_.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelcgzyqb4v/prophet_model-20230513155642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/p40sgo2b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/5tywdubo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30458', 'data', 'file=/tmp/tmprjsbnnc6/p40sgo2b.json', 'init=/tmp/tmprjsbnnc6/5tywdubo.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model4y8fh6m5/prophet_model-20230513155643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/mh9sab4c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/bmk1org_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95929', 'data', 'file=/tmp/tmprjsbnnc6/mh9sab4c.json', 'init=/tmp/tmprjsbnnc6/bmk1org_.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelyan5mkdr/prophet_model-20230513155643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/qvxphk0n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/unayqmbt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61539', 'data', 'file=/tmp/tmprjsbnnc6/qvxphk0n.json', 'init=/tmp/tmprjsbnnc6/unayqmbt.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelmm0uyq8a/prophet_model-20230513155644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/qrjnoyhy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/h5o3qyr6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77389', 'data', 'file=/tmp/tmprjsbnnc6/qrjnoyhy.json', 'init=/tmp/tmprjsbnnc6/h5o3qyr6.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelcax00gk6/prophet_model-20230513155644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/rry5fxjf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2e7usjba.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45128', 'data', 'file=/tmp/tmprjsbnnc6/rry5fxjf.json', 'init=/tmp/tmprjsbnnc6/2e7usjba.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model86yzwt31/prophet_model-20230513155645.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/_b_2zh_s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/69e9017b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80152', 'data', 'file=/tmp/tmprjsbnnc6/_b_2zh_s.json', 'init=/tmp/tmprjsbnnc6/69e9017b.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelh1q7s1xs/prophet_model-20230513155646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/emuapwux.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/b9pqmi2e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79206', 'data', 'file=/tmp/tmprjsbnnc6/emuapwux.json', 'init=/tmp/tmprjsbnnc6/b9pqmi2e.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeliw2gse33/prophet_model-20230513155646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/hocrfx35.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/7cc67om2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87198', 'data', 'file=/tmp/tmprjsbnnc6/hocrfx35.json', 'init=/tmp/tmprjsbnnc6/7cc67om2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modele9bk9n6x/prophet_model-20230513155646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/fb9xxr_1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/buf19d5e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61673', 'data', 'file=/tmp/tmprjsbnnc6/fb9xxr_1.json', 'init=/tmp/tmprjsbnnc6/buf19d5e.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelbq6s3r4v/prophet_model-20230513155647.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/44staba6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/drydqsbx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81069', 'data', 'file=/tmp/tmprjsbnnc6/44staba6.json', 'init=/tmp/tmprjsbnnc6/drydqsbx.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelo3pt7svr/prophet_model-20230513155648.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/be_wd3_3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tutocbzk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1306', 'data', 'file=/tmp/tmprjsbnnc6/be_wd3_3.json', 'init=/tmp/tmprjsbnnc6/tutocbzk.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeldbe0qo3p/prophet_model-20230513155648.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/r41dzm3k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/669vkl6y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=709', 'data', 'file=/tmp/tmprjsbnnc6/r41dzm3k.json', 'init=/tmp/tmprjsbnnc6/669vkl6y.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelszsu2b36/prophet_model-20230513155649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/314854yy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/www6l0ux.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26578', 'data', 'file=/tmp/tmprjsbnnc6/314854yy.json', 'init=/tmp/tmprjsbnnc6/www6l0ux.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model5ifpkzhw/prophet_model-20230513155649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/0s18ewib.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ofqyw8mu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53995', 'data', 'file=/tmp/tmprjsbnnc6/0s18ewib.json', 'init=/tmp/tmprjsbnnc6/ofqyw8mu.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelxz3pzum6/prophet_model-20230513155650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ayl_2ro8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/koi7go_n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53503', 'data', 'file=/tmp/tmprjsbnnc6/ayl_2ro8.json', 'init=/tmp/tmprjsbnnc6/koi7go_n.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeljhuqili8/prophet_model-20230513155650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/peku7x_u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/q8c55eoq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50619', 'data', 'file=/tmp/tmprjsbnnc6/peku7x_u.json', 'init=/tmp/tmprjsbnnc6/q8c55eoq.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelvmjt2pbj/prophet_model-20230513155651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/wdqbr32x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/iuh0fq7y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60524', 'data', 'file=/tmp/tmprjsbnnc6/wdqbr32x.json', 'init=/tmp/tmprjsbnnc6/iuh0fq7y.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelyf6jv4oz/prophet_model-20230513155652.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ykpzp79m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/twq578y5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38710', 'data', 'file=/tmp/tmprjsbnnc6/ykpzp79m.json', 'init=/tmp/tmprjsbnnc6/twq578y5.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelfu9b7dvf/prophet_model-20230513155653.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/z753n2cc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/151od077.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66768', 'data', 'file=/tmp/tmprjsbnnc6/z753n2cc.json', 'init=/tmp/tmprjsbnnc6/151od077.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelfiig33q2/prophet_model-20230513155654.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/8sjz5fee.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ga44pya8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84426', 'data', 'file=/tmp/tmprjsbnnc6/8sjz5fee.json', 'init=/tmp/tmprjsbnnc6/ga44pya8.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelxdf6qed4/prophet_model-20230513155654.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/762vfeed.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/odghvtu4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85754', 'data', 'file=/tmp/tmprjsbnnc6/762vfeed.json', 'init=/tmp/tmprjsbnnc6/odghvtu4.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelob1phfwd/prophet_model-20230513155655.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:56:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/rbnc02iu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2gfhppyk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27938', 'data', 'file=/tmp/tmprjsbnnc6/rbnc02iu.json', 'init=/tmp/tmprjsbnnc6/2gfhppyk.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelaj4aaidt/prophet_model-20230513155656.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:56:56 - cmdstanpy - INFO - Chain [1] start processing
# ...
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/fxp23wnc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/e4chy1j8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34179', 'data', 'file=/tmp/tmprjsbnnc6/fxp23wnc.json', 'init=/tmp/tmprjsbnnc6/e4chy1j8.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modeld60jlrdo/prophet_model-20230513161113.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ay9zrhqt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/szaud06v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84671', 'data', 'file=/tmp/tmprjsbnnc6/ay9zrhqt.json', 'init=/tmp/tmprjsbnnc6/szaud06v.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model1ggu7j3w/prophet_model-20230513161116.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/vn2bk3rs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/d_62b_kx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36529', 'data', 'file=/tmp/tmprjsbnnc6/vn2bk3rs.json', 'init=/tmp/tmprjsbnnc6/d_62b_kx.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model1fitqo7l/prophet_model-20230513161119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/2_rdwio3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/gips__d_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38390', 'data', 'file=/tmp/tmprjsbnnc6/2_rdwio3.json', 'init=/tmp/tmprjsbnnc6/gips__d_.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelmaqfdy25/prophet_model-20230513161121.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/_4zk9csf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/czp8nhto.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77004', 'data', 'file=/tmp/tmprjsbnnc6/_4zk9csf.json', 'init=/tmp/tmprjsbnnc6/czp8nhto.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model074bwgmc/prophet_model-20230513161125.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/u97px_qa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ik77kkj1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31549', 'data', 'file=/tmp/tmprjsbnnc6/u97px_qa.json', 'init=/tmp/tmprjsbnnc6/ik77kkj1.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modell4tc_9s8/prophet_model-20230513161128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/wd_suplk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/242v6973.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26366', 'data', 'file=/tmp/tmprjsbnnc6/wd_suplk.json', 'init=/tmp/tmprjsbnnc6/242v6973.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelksterjz1/prophet_model-20230513161130.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/157vvwbd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/sfd8f69e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89490', 'data', 'file=/tmp/tmprjsbnnc6/157vvwbd.json', 'init=/tmp/tmprjsbnnc6/sfd8f69e.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model3dryrvqp/prophet_model-20230513161132.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/34nlv8fi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/gf05zgw2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38803', 'data', 'file=/tmp/tmprjsbnnc6/34nlv8fi.json', 'init=/tmp/tmprjsbnnc6/gf05zgw2.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model4p6n2myv/prophet_model-20230513161135.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/a14qg_4n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/qxezlgru.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78769', 'data', 'file=/tmp/tmprjsbnnc6/a14qg_4n.json', 'init=/tmp/tmprjsbnnc6/qxezlgru.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelfivjtt5m/prophet_model-20230513161138.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/9d_x_ei6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ho5g7c_e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74225', 'data', 'file=/tmp/tmprjsbnnc6/9d_x_ei6.json', 'init=/tmp/tmprjsbnnc6/ho5g7c_e.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelw0gy256t/prophet_model-20230513161142.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/mymnkn3z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/wa9lf8rq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92703', 'data', 'file=/tmp/tmprjsbnnc6/mymnkn3z.json', 'init=/tmp/tmprjsbnnc6/wa9lf8rq.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelj0n72ux1/prophet_model-20230513161145.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/oll2u2si.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/hz60m9rq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40188', 'data', 'file=/tmp/tmprjsbnnc6/oll2u2si.json', 'init=/tmp/tmprjsbnnc6/hz60m9rq.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelb2er9t9m/prophet_model-20230513161147.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/smn28t9m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/t9ojzrhm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42918', 'data', 'file=/tmp/tmprjsbnnc6/smn28t9m.json', 'init=/tmp/tmprjsbnnc6/t9ojzrhm.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modellbwhgdpb/prophet_model-20230513161150.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/gb_meppr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tpg5ezlk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11053', 'data', 'file=/tmp/tmprjsbnnc6/gb_meppr.json', 'init=/tmp/tmprjsbnnc6/tpg5ezlk.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelhla6r4xe/prophet_model-20230513161154.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/tliydhgj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/vjvouklh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76420', 'data', 'file=/tmp/tmprjsbnnc6/tliydhgj.json', 'init=/tmp/tmprjsbnnc6/vjvouklh.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model3ts0q3or/prophet_model-20230513161156.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:11:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:11:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/9x224w_v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/56gv9yad.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92935', 'data', 'file=/tmp/tmprjsbnnc6/9x224w_v.json', 'init=/tmp/tmprjsbnnc6/56gv9yad.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model2acd5ma5/prophet_model-20230513161200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:12:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:12:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/bz3xthhj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/yq6arhe9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10151', 'data', 'file=/tmp/tmprjsbnnc6/bz3xthhj.json', 'init=/tmp/tmprjsbnnc6/yq6arhe9.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model2pqdkzjk/prophet_model-20230513161202.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:12:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:12:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/6f6zlrej.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/1q1igu9o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37423', 'data', 'file=/tmp/tmprjsbnnc6/6f6zlrej.json', 'init=/tmp/tmprjsbnnc6/1q1igu9o.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelhqo6rv3z/prophet_model-20230513161205.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:12:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:12:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/3r7vs38c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/ls18_8oo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22794', 'data', 'file=/tmp/tmprjsbnnc6/3r7vs38c.json', 'init=/tmp/tmprjsbnnc6/ls18_8oo.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_modelapc366v4/prophet_model-20230513161208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:12:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:12:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/6evoy5op.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprjsbnnc6/yr93rlyr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57730', 'data', 'file=/tmp/tmprjsbnnc6/6evoy5op.json', 'init=/tmp/tmprjsbnnc6/yr93rlyr.json', 'output', 'file=/tmp/tmprjsbnnc6/prophet_model1o6e9igk/prophet_model-20230513161210.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:12:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:12:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
def prep_prophet(prophet_pred, data1):
  print(prophet_pred.info())
  prophet_pred = prophet_pred.rename(columns = {'ds': 'date'}).set_index('date')
  scale = MinMaxScaler()
  main_data = data1.join(prophet_pred,how = 'left')
  returned = main_data.loc['2016-01-01':'2023-03-01']
  returned['yhat'] = scale.fit_transform(returned[['yhat']])
  return returned['yhat']

Goog_data_proph = prep_prophet(GOOG_data, test_data)[10:]
Msft_train_proph= prep_prophet(MSFT_data, train_data)[10:1623]
Msft_test_proph = prep_prophet(MSFT_data, train_data)[1623:]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1867 non-null   datetime64[ns]
#  1   yhat    1867 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 29.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1867 non-null   datetime64[ns]
#  1   yhat    1867 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 29.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      1867 non-null   datetime64[ns]
#  1   yhat    1867 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 29.3 KB
# None

# %% [markdown]
# ## 2.3 Create Dataset to train hybrid model

# %%
from keras.saving.legacy.save import load_model

#create training data using predictions from lstm and prophet
lstm = load_model('main_models/LSTM_model1.h5')
def return_hybrid_data(lstm_model, prophet_data, LSTM_data, LSTM_target):
  preds_dict = {}
  preds_dict['lstm_pred'] = lstm_model.predict(LSTM_data).flatten()
  print(lstm_model.predict(LSTM_data).shape)
  preds_dict['prophet_pred'] = np.array(prophet_data)
  print(preds_dict)
  hybrid_mid_train = pd.DataFrame(preds_dict)
  hybrid_train, target = lstm_split(hybrid_mid_train, LSTM_target, len(hybrid_mid_train))
  return hybrid_train, target, hybrid_mid_train

hybrid_train, target, no_split = return_hybrid_data(lstm, Msft_train_proph, X_train, y_train)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 51/51 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# (1613, 1)
# {'lstm_pred': array([0.0182527 , 0.01899782, 0.01869927, ..., 0.72081465, 0.71402174,
#        0.6809436 ], dtype=float32), 'prophet_pred': array([0.06842313, 0.12488803, 0.12614129, ..., 0.87706923, 0.88327018,
#        0.89477937])}

# %% [markdown]
# ### 2.3.1 Configure Hybrid Model

# %%
print(no_split)
# Out:
# [[[0.0182527  0.06842313]
#   [0.01899782 0.12488803]
#   [0.01869927 0.12614129]
#   ...
#   [0.02054117 0.15033082]
#   [0.02441651 0.15523985]
#   [0.02551921 0.13546846]]
#
#  [[0.01899782 0.12488803]
#   [0.01869927 0.12614129]
#   [0.01954149 0.12783893]
#   ...
#   [0.02441651 0.15523985]
#   [0.02551921 0.13546846]
#   [0.02650535 0.13729568]]
#
#  [[0.01869927 0.12614129]
#   [0.01954149 0.12783893]
#   [0.0236698  0.13709511]
#   ...
#   [0.02551921 0.13546846]
#   [0.02650535 0.13729568]
#   [0.02791957 0.13894643]]
#
#  ...
#
#  [[0.62984949 0.89214601]
#   [0.62001681 0.89415114]
#   [0.63811839 0.89918697]
#   ...
#   [0.70910531 0.89045216]
#   [0.70919651 0.86704187]
#   [0.71108228 0.87370352]]
#
#  [[0.62001681 0.89415114]
#   [0.63811839 0.89918697]
#   [0.66749346 0.86068306]
#   ...
#   [0.70919651 0.86704187]
#   [0.71108228 0.87370352]
#   [0.72081465 0.87706923]]
#
#  [[0.63811839 0.89918697]
#   [0.66749346 0.86068306]
#   [0.66627109 0.8674596 ]
#   ...
#   [0.71108228 0.87370352]
#   [0.72081465 0.87706923]
#   [0.71402174 0.88327018]]]

# %%
LR = 0.01
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.optimizers import Adam

#General LSTM model based on randomsearch results
def multiple_models(x_train, y_train):
    hybrid = Sequential()
    hybrid.add(LSTM(units = 98, activation = "sigmoid", input_shape = (x_train.shape[1], x_train.shape[2]), return_sequences = False))
    hybrid.add(Dropout(0.5))
    hybrid.add(Dense(units =1))
    hybrid.compile(loss = 'mean_squared_error', optimizer = Adam(lr = LR), metrics = ["mae"])
    Early_stop = EarlyStopping(monitor='loss', min_delta=0, 
                              patience=25, verbose=1, mode='auto',
                              baseline=0, restore_best_weights=True)
    hybrid = hybrid.fit(x_train, y_train, epochs = 200, batch_size = 24, callbacks = [Early_stop])
    return hybrid
    
#train the hybrid model
hybrid1 = multiple_models(hybrid_train, target)
hybrid1.model.save('main_models/hybrid1.h5')

# %%
#Single Company Linear hybrid model
from sklearn.linear_model import LinearRegression

def create_linear(train_data, train_target):
  Lin_model = LinearRegression()
  Lin_model = Lin_Model.fit(train_data, train_target) 
  return Lin_model

linear_sing_hybrid = create_linear(no_split, y_train)

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(hybrid1.history['loss'])+1, 1)
plt.plot(x,hybrid1.history['loss'], "b", label= "mse")
plt.plot(x,hybrid1.history['mae'], "r", label= "mae")

plt.title(" Hybrid MSE vs MAE During Training")
plt.xlabel('epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.4 Test Single Company Models (LSTM vs. Hybrid)

# %%
#Configure LSTM test using google data and micosoft validation data
print(test_data)
goog_test, goog_target = lstm_split(test_data, test_target, len(test_data))
LSTM_predictions = lstm.predict(goog_test)
LSTM_validation = lstm.predict(X_test).flatten()

#Generate google and microsoft test data for hybrid model
google_ft, google_target, goog_no_split = return_hybrid_data(lstm, Goog_data_proph, goog_test, goog_target)
hybrid_val_feat, hybrid_val_target, val_no_split = return_hybrid_data(lstm, Msft_test_proph, X_test, y_test)

#Generate linear predictions

# %% [markdown]
# ### 2.4.1 LSTM vs Hybrid predictions of Microsoft Validation Data

# %%
#ploting MSFT LSTM vs Hybrid predictions
import matplotlib.pyplot as plt
hybrid_MSFT_predictions = hybrid1.model.predict(hybrid_val_feat)

x=np.arange(1,len(LSTM_validation[10:])+1,1)
plt.plot(x, LSTM_validation[10:], "r", label= "LSTM")
plt.plot(x,hybrid_MSFT_predictions, "g", label= "Hybrid")
plt.plot(x,y_test[10:], "b", label= "Target")

plt.title(" MSFT LSTM vs Hybrid trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 0s 4ms/step

# %% [markdown]
# **From the graph above we can see that the performance of the hybrid model(green) on validation data has reduced accuracy compared to the LSTM model (red)**

# %% [markdown]
# ### 2.4.2 Google Predicitions on Microsoft Model ( LSTM vs Hybrid)

# %%
#ploting GOOG LSTM vs Hybrid predictions
import matplotlib.pyplot as plt
goog_predictions_hybrid = hybrid1.model.predict(google_ft)

x=np.arange(1,len(LSTM_predictions[10:])+1,1)
plt.plot(x, LSTM_predictions[10:], "r", label= "LSTM")
plt.plot(x,goog_predictions_hybrid, "orange", label= "Hybrid")
plt.plot(x,goog_target[10:], "b", label= "Target")

plt.title(" GOOG  LSTM vs Hybrid trends")
plt.xlabel('Days')
plt.legend()
plt.show()
# Out:
# 56/56 [==============================] - 0s 3ms/step

# %% [markdown]
# F**rom the graph above we can see that the performance of the hybrid model(orange) for an unseen stock (GOOG) has reduced accuracy compared to the LSTM model (red)**

# %%
#define function to evaluate model results
def compute_metrics(true_series, forecast):
    """Helper to print MSE and MAE"""
    mse = tf.keras.metrics.MeanSquaredError()
    mse.update_state(true_series, forecast)
    mae = tf.keras.metrics.MeanAbsoluteError()
    mae.update_state(true_series, forecast)
    print(f"the mean square error of the predictions is {mse.result().numpy()}, and the mean absolute error of the predictions is {mae.result().numpy()}")
    return mse.result().numpy(), mae.result().numpy()

# %% [markdown]
# # 3.0 Building the Expanded Hybrid Model

# %%
LR = 0.01 
def create_data_lists(list_of_feats, list_of_targets):
  training_list = []
  target_list = []
  for data, target in zip(list_of_feats, list_of_targets):
    data_x, data_y = lstm_split(data, target, len(data))
    print(data_x.shape)
    training_list.append(data_x)
    target_list.append(data_y)
  return training_list, target_list

#Train each of the lstm models on training companies
path = '/content/BigData/Project_Deliverables_PansyAhmed_AdamGreen/expanded_data/'
ticker_list = ["MSFT", "NFLX", "AMZN", "TSLA"]
hybrid_scalers, targets, frames = scale(path)
training_list, target_list = create_data_lists(frames, targets)

for tick, x_train, y_train in zip(ticker_list, training_list, target_list):
  model = multiple_models(x_train, y_train)
  model.model.save('sub_models/'+tick+'_lstm.h5')
# Out:
# MSFT_dataframe.csv
# NFLX_dataframe.csv
# TSLA_dataframe.csv
# AMZN_dataframe.csv
# (1792, 10, 18)
# (1792, 10, 18)
# (1792, 10, 18)
# (1792, 10, 18)
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 75/75 [==============================] - 2s 8ms/step - loss: 0.0449 - mae: 0.1480
# Epoch 2/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0099 - mae: 0.0771
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0076 - mae: 0.0667
# Epoch 4/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0058 - mae: 0.0576
# Epoch 5/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0054 - mae: 0.0553
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0044 - mae: 0.0498
# Epoch 7/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0043 - mae: 0.0495
# Epoch 8/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0041 - mae: 0.0497
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0042 - mae: 0.0485
# Epoch 10/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0034 - mae: 0.0447
# Epoch 11/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0034 - mae: 0.0453
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0032 - mae: 0.0437
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0032 - mae: 0.0436
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0036 - mae: 0.0453
# Epoch 15/200
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0030 - mae: 0.0409
# Epoch 16/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0440
# Epoch 17/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0036 - mae: 0.0457
# Epoch 18/200
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0032 - mae: 0.0430
# Epoch 19/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0428
# Epoch 20/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0034 - mae: 0.0435
# Epoch 21/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0030 - mae: 0.0419
# Epoch 22/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0420
# Epoch 23/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0033 - mae: 0.0444
# Epoch 24/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0030 - mae: 0.0414
# Epoch 25/200
# 72/75 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0426Restoring model weights from the end of the best epoch: 24.
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0425
# Epoch 25: early stopping
# Epoch 1/200
# 75/75 [==============================] - 2s 7ms/step - loss: 0.1392 - mae: 0.2551
# Epoch 2/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0255 - mae: 0.1273
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0174 - mae: 0.1037
# Epoch 4/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0131 - mae: 0.0886
# Epoch 5/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0105 - mae: 0.0807
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0087 - mae: 0.0732
# Epoch 7/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0068 - mae: 0.0643
# Epoch 8/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0060 - mae: 0.0604
# Epoch 9/200
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0051 - mae: 0.0549
# Epoch 10/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0529
# Epoch 11/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0483
# Epoch 12/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0485
# Epoch 13/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0468
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0036 - mae: 0.0466
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0035 - mae: 0.0453
# Epoch 16/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0040 - mae: 0.0486
# Epoch 17/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0032 - mae: 0.0430
# Epoch 18/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0041 - mae: 0.0491
# Epoch 19/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0030 - mae: 0.0422
# Epoch 20/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0423
# Epoch 21/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0423
# Epoch 22/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0032 - mae: 0.0439
# Epoch 23/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0032 - mae: 0.0433
# Epoch 24/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0029 - mae: 0.0412
# Epoch 25/200
# 73/75 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0433Restoring model weights from the end of the best epoch: 24.
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0431
# Epoch 25: early stopping
# Epoch 1/200
# 75/75 [==============================] - 2s 8ms/step - loss: 0.0778 - mae: 0.1951
# Epoch 2/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0141 - mae: 0.0926
# Epoch 3/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0096 - mae: 0.0758
# Epoch 4/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0072 - mae: 0.0636
# Epoch 5/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0063 - mae: 0.0600
# Epoch 6/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0055 - mae: 0.0550
# Epoch 7/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0046 - mae: 0.0501
# Epoch 8/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0050 - mae: 0.0512
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0039 - mae: 0.0457
# Epoch 10/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0036 - mae: 0.0436
# Epoch 11/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0035 - mae: 0.0439
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0037 - mae: 0.0434
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0038 - mae: 0.0456
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0036 - mae: 0.0435
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0031 - mae: 0.0418
# Epoch 16/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0031 - mae: 0.0407
# Epoch 17/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0420
# Epoch 18/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0458
# Epoch 19/200
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0031 - mae: 0.0403
# Epoch 20/200
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0031 - mae: 0.0411
# Epoch 21/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0029 - mae: 0.0401
# Epoch 22/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0033 - mae: 0.0417
# Epoch 23/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0033 - mae: 0.0416
# Epoch 24/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0030 - mae: 0.0409
# Epoch 25/200
# 70/75 [===========================>..] - ETA: 0s - loss: 0.0030 - mae: 0.0400Restoring model weights from the end of the best epoch: 21.
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0030 - mae: 0.0401
# Epoch 25: early stopping
# Epoch 1/200
# 75/75 [==============================] - 2s 8ms/step - loss: 0.1893 - mae: 0.2885
# Epoch 2/200
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0317 - mae: 0.1422
# Epoch 3/200
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0216 - mae: 0.1160
# Epoch 4/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0159 - mae: 0.1019
# Epoch 5/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0135 - mae: 0.0924
# Epoch 6/200
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0111 - mae: 0.0826
# Epoch 7/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0096 - mae: 0.0764
# Epoch 8/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0090 - mae: 0.0734
# Epoch 9/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0073 - mae: 0.0659
# Epoch 10/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0065 - mae: 0.0625
# Epoch 11/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0062 - mae: 0.0613
# Epoch 12/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0059 - mae: 0.0590
# Epoch 13/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0055 - mae: 0.0574
# Epoch 14/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0049 - mae: 0.0539
# Epoch 15/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0047 - mae: 0.0531
# Epoch 16/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0044 - mae: 0.0514
# Epoch 17/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0042 - mae: 0.0506
# Epoch 18/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0041 - mae: 0.0496
# Epoch 19/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0042 - mae: 0.0499
# Epoch 20/200
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0037 - mae: 0.0471
# Epoch 21/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0037 - mae: 0.0474
# Epoch 22/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0037 - mae: 0.0476
# Epoch 23/200
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0034 - mae: 0.0451
# Epoch 24/200
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0463
# Epoch 25/200
# 75/75 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0485Restoring model weights from the end of the best epoch: 23.
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0485
# Epoch 25: early stopping

# %% [markdown]
# ## 3.1 Train Expanded Hybrid Model Using Predictions of all Sub-Models

# %%
#Create Train Data for Hybrid Model Using Microsoft Predictions
from keras.saving.legacy.save import load_model
import os
def hybrid_trainer(direct, ticker_list, hybrid_train):
    preds_dict = {}
    path = direct
    for num, model in enumerate(os.listdir(path)):
        model = load_model(path+model)
        prediction = model.predict(hybrid_train).flatten()
        print(prediction.shape)
        preds_dict[ticker_list[num]] = prediction
    preds_df = pd.DataFrame(preds_dict)
    return preds_df

#generate training data for expanded hybrid model
hybrid_training_data =  hybrid_trainer('sub_models/', ticker_list, X_train) 
hybrid_training_data['prophet'] = np.array(Msft_train_proph)
hybrid_training_data, y_train = lstm_split(hybrid_training_data, target_list[0], len(hybrid_training_data))
# Out:
# 51/51 [==============================] - 0s 4ms/step
# (1613,)
# 51/51 [==============================] - 1s 4ms/step
# (1613,)
# 51/51 [==============================] - 0s 3ms/step
# (1613,)
# 51/51 [==============================] - 0s 4ms/step
# (1613,)

# %%
#Create and train the expanded hybrid model
hybrid_expanded = multiple_models(hybrid_training_data, y_train)
hybrid_expanded.model.save('main_models/hybrid_expanded.h5')
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 67/67 [==============================] - 2s 9ms/step - loss: 0.1904 - mae: 0.3017
# Epoch 2/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0365 - mae: 0.1530
# Epoch 3/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0256 - mae: 0.1276
# Epoch 4/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0173 - mae: 0.1055
# Epoch 5/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0129 - mae: 0.0892
# Epoch 6/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0098 - mae: 0.0765
# Epoch 7/200
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0079 - mae: 0.0694
# Epoch 8/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0076 - mae: 0.0665
# Epoch 9/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0068 - mae: 0.0633
# Epoch 10/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0062 - mae: 0.0594
# Epoch 11/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0057 - mae: 0.0567
# Epoch 12/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0060 - mae: 0.0595
# Epoch 13/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0055 - mae: 0.0558
# Epoch 14/200
# 67/67 [==============================] - 1s 10ms/step - loss: 0.0052 - mae: 0.0544
# Epoch 15/200
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0523
# Epoch 16/200
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0518
# Epoch 17/200
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0524
# Epoch 18/200
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0489
# Epoch 19/200
# 67/67 [==============================] - 1s 10ms/step - loss: 0.0046 - mae: 0.0521
# Epoch 20/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0045 - mae: 0.0513
# Epoch 21/200
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0529
# Epoch 22/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0046 - mae: 0.0512
# Epoch 23/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0043 - mae: 0.0498
# Epoch 24/200
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0049 - mae: 0.0535
# Epoch 25/200
# 67/67 [==============================] - ETA: 0s - loss: 0.0052 - mae: 0.0559Restoring model weights from the end of the best epoch: 18.
# 67/67 [==============================] - 1s 7ms/step - loss: 0.0052 - mae: 0.0559
# Epoch 25: early stopping

# %% [markdown]
# ## 3.2 Test the Expanded Hybrid Model on Microsoft and Goole Test Data

# %%
#Configure hybrid model testing data based on predictions from each of the four underlying models and prophet
google_test = {}
microsoft_test = {}
path = 'sub_models/'
for num, model in enumerate(os.listdir(path)):
  model = load_model(path+model)
  goog_preds = model.predict(goog_test).flatten()
  micro_preds = model.predict(X_test).flatten()
  google_test[ticker_list[num]] = goog_preds
  microsoft_test[ticker_list[num]] = micro_preds
google_test = pd.DataFrame(google_test)
microsoft_test = pd.DataFrame(microsoft_test)

#set Prophet data
google_test['prophet'] = np.array(Goog_data_proph)
microsoft_test['prophet'] = np.array(Msft_test_proph)
#Create final test data for hybrid model
google_test, goog_y = lstm_split(google_test, goog_target, len(google_test))
microsoft_test, msft_y = lstm_split(microsoft_test, y_test, len(microsoft_test))
# Out:
# 56/56 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 56/56 [==============================] - 0s 4ms/step
# 6/6 [==============================] - 0s 4ms/step
# 56/56 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 5ms/step
# 56/56 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 4ms/step

# %%
#Predict google and microsoft test data using the trained hybrid model
hybrid_expanded = load_model('main_models/hybrid_expanded.h5')
expanded_msft_predictions = hybrid_expanded.predict(microsoft_test)
expanded_goog_predictions = hybrid_expanded.predict(google_test)
# Out:
# 6/6 [==============================] - 0s 4ms/step
# 56/56 [==============================] - 0s 4ms/step

# %%
#prepare all predictions
#lstm
msft_lstm_mse, msft_lstm_mae = compute_metrics(y_test, LSTM_MSFT_test)
goog_lstm_mse, goog_lstm_mae = compute_metrics(goog_target, LSTM_predictions)

#single hybrid
msft_single_mse, msft_single_mae = compute_metrics(y_test[10:], hybrid_MSFT_predictions)
goog_sinlge_mse, goog_single_mae = compute_metrics(google_target, goog_predictions_hybrid)

#expanded_hybrid
msft_expanded_mse, msft_expanded_mae = compute_metrics(msft_y, expanded_msft_predictions)
goog_expanded_mse, goog_expanded_mae = compute_metrics(goog_y, expanded_goog_predictions)
# Out:
# the mean square error of the predictions is 0.0007448047399520874, and the mean absolute error of the predictions is 0.02097177505493164
# the mean square error of the predictions is 0.00040679037920199335, and the mean absolute error of the predictions is 0.015037541277706623
# the mean square error of the predictions is 0.0022203538101166487, and the mean absolute error of the predictions is 0.038844939321279526
# the mean square error of the predictions is 0.002196311252191663, and the mean absolute error of the predictions is 0.036686718463897705
# the mean square error of the predictions is 0.012377820909023285, and the mean absolute error of the predictions is 0.1010458692908287
# the mean square error of the predictions is 0.0013577045174315572, and the mean absolute error of the predictions is 0.026144595816731453

# %%
import seaborn as sns
x = ['Base LSTM', 'Single Company Hybrid Model', "Expanded Hybrid Model"]
msft = [msft_lstm_mae, msft_single_mae, msft_expanded_mae]
goog = [goog_lstm_mae, goog_single_mae, goog_expanded_mae]
X_axis = np.arange(len(x))
plt.figure(figsize=(10, 6))
plt.bar(X_axis - 0.2, msft, 0.4, label = 'Microsoft Test')
plt.bar(X_axis + 0.2, goog, 0.4, label = 'Google Test')
  
plt.xticks(X_axis, x)
plt.xlabel("Models")
plt.ylabel("Mean Absolute Error (Scaled)")
plt.title("Comparison of Model Mean Absolute Error Across Models")
plt.legend()
plt.show()


plt.plot(goog_y, label="actual")
plt.plot(expanded_goog_predictions, label="predicted")
goog_y, expanded_goog_predictions
plt.xlabel("Timesteps")
plt.ylabel("Value (Scaled)")
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.legend()
plt.show()
